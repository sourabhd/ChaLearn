# %% [markdown]
# <a href="https://colab.research.google.com/github/sourabhd/ChaLearn/blob/master/5_DeepDiveIntoNeuralNetworks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Dive into Neural Networks

# %% [markdown]
# ## Model

# %% [markdown]
# ### Logistic Regression: Simplest neural network : Linear classifier

# %% [markdown]
# ### Solving nonlinear problems like XOR: add a hidden layer

# %% [markdown]
# ### Going deep ?

# %% [markdown]
# ## Loss Function

# %% [markdown]
# ### Definition

# %% [markdown]
# #### Simplest loss function: Mean Squared Error

# %% [markdown]
# #### Most commonly used algorithm: Cross Entropy

# %% [markdown]
# ### Algorithm

# %% [markdown]
# #### Optimisation algorithms landscape

# %% [markdown]
# #### Most common algorithm is the simplest one: Stochastic Gradient Descent (SGD)

# %%
from IPython.display import Image
Image("https://www.researchgate.net/profile/Augusto_Pacheco-Comer/publication/298786734/figure/fig13/AS:669050770300942@1536525542529/Gradient-descent-algorithm-direction-Equation-1-Image-courtesy-of-Andrew-Ng.jpg")

# %% [markdown]
# #### Making the algorithm efficient: backpropagation
